# %% [markdown]
# # Maze Visualization Demo
#
# This notebook demonstrates the visualization capabilities of the maze runner game using the visualization utilities from the project.

# %%
import sys
import pygame
import time
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# Import our maze game modules
from src.maze import create_maze
from src.visualization import visualize_maze, JupyterExplorer
from src.explorer import Explorer
from src.constants import WINDOW_SIZE
# Out:
# pygame 2.6.1 (SDL 2.28.4, Python 3.12.9)
# Hello from the pygame community. https://www.pygame.org/contribute.html

# %% [markdown]
# ## Initialize Pygame for Jupyter
#
# We need to initialize Pygame in a way that works with Jupyter notebooks.

# %%
# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((WINDOW_SIZE, WINDOW_SIZE))
pygame.display.set_caption("Maze Explorer - Jupyter Visualization")

# %% [markdown]
# ## Create and Visualize a Random Maze
#
# Let's create a random maze and visualize it using the visualization utilities.

# %%
# Create and visualize a random maze
maze = create_maze(30, 30, "random")
visualize_maze(maze, screen)

# %% [markdown]
# ## Animated Maze Solving
#
# Let's use the JupyterExplorer to solve the maze with animation.

# %%
# Create maze and explorer
maze = create_maze(30, 30, "random")
explorer = JupyterExplorer(maze, screen)

# Run the explorer
time_taken, moves = explorer.solve()
print(f"Maze solved in {time_taken:.2f} seconds")
print(f"Number of moves: {len(moves)}")
# Out:
# === Maze Exploration Statistics ===
# Total time taken: 32.82 seconds
# Total moves made: 181
# Number of backtrack operations: 0
# Average moves per second: 5.51
# ==================================
#
# Maze solved in 32.82 seconds
# Number of moves: 181

# %% [markdown]
# ## Compare Different Maze Types
#
# Let's compare the visualization of random and static mazes.

# %%
# Initialize Pygame
pygame.init()
screen = pygame.display.set_mode((WINDOW_SIZE, WINDOW_SIZE))
pygame.display.set_caption("Maze Explorer - Jupyter Visualization")

# Create and visualize a random maze
random_maze = create_maze(30, 30, "random")
print("Random Maze:")
visualize_maze(random_maze, screen)

# Create and visualize a static maze
static_maze = create_maze(30, 30, "static")
print("Static Maze:")
visualize_maze(static_maze, screen)
# Out:
# Random Maze:
# Static Maze:

# %% [markdown]
# ## Performance Analysis
#
# Let's analyze the performance of the automated explorer on different maze types.

# %%
def run_exploration(maze_type, width, height):
    maze = create_maze(width, height, maze_type)
    explorer = Explorer(maze, visualize=False)
    start_time = time.time()
    time_taken, moves = explorer.solve()
    return {
        'maze_type': maze_type,
        'time_taken': time_taken,
        'moves': len(moves),
        'moves_per_second': len(moves) / time_taken
    }

# Run multiple explorations
results = []
for maze_type in ['random', 'static']:
    for _ in range(3):  # Run each type 3 times
        result = run_exploration(maze_type, 30, 30)
        results.append(result)
print("Simulation Done")
# Display results
df = pd.DataFrame(results)
print("Exploration Results:")
print(df.groupby('maze_type').mean())
# Out:
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 341
# Number of backtrack operations: 0
# Average moves per second: 1199880.59
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 569
# Number of backtrack operations: 0
# Average moves per second: 1151814.18
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 264
# Number of backtrack operations: 0
# Average moves per second: 1252597.57
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 1279
# Number of backtrack operations: 0
# Average moves per second: 1200652.38
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 1279
# Number of backtrack operations: 0
# Average moves per second: 823536.20
# ==================================
#
#
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 1279
# Number of backtrack operations: 0
# Average moves per second: 1220039.76
# ==================================
#
# Simulation Done
# Exploration Results:
#            time_taken        moves  moves_per_second
# maze_type
# random       0.000330   391.333333      1.201431e+06
# static       0.001222  1279.000000      1.081409e+06

# %% [markdown]
# # My Attempt

# %%
import matplotlib.pyplot as plt
import numpy as np

# Algorithm labels
algorithms = ['Right Hand', 'BFS', 'A*']

# Data
time_taken = [0.0019645691, 0.0015385151, 0.0011959076]
moves_made = [1279, 128, 128]
moves_per_sec = [651033.35, 83197.10, 107031.68]

# Color mapping
colors = {
    'Right Hand': 'orange',
    'BFS': 'deepskyblue',
    'A*': 'mediumseagreen'
}

# Match bar colors with algorithm order
bar_colors = [colors[algo] for algo in algorithms]

# Create subplots
fig, axs = plt.subplots(1, 3, figsize=(18, 5))

# Plot: Total Time Taken
axs[0].bar(algorithms, time_taken, color=bar_colors)
axs[0].plot(algorithms, time_taken, color='gray', linestyle='--', marker='o')
axs[0].set_title('Total Time Taken (s)')
axs[0].set_ylabel('Seconds')

# Plot: Total Moves Made
axs[1].bar(algorithms, moves_made, color=bar_colors)
axs[1].plot(algorithms, moves_made, color='gray', linestyle='--', marker='o')
axs[1].set_title('Total Moves Made')
axs[1].set_ylabel('Moves')

# Plot: Average Moves per Second
axs[2].bar(algorithms, moves_per_sec, color=bar_colors)
axs[2].plot(algorithms, moves_per_sec, color='gray', linestyle='--', marker='o')
axs[2].set_title('Average Moves per Second')
axs[2].set_ylabel('Moves/sec')

# Layout adjustment
plt.tight_layout()
plt.show()

# %%
from src.myExplorer import myExplorer

# Create maze and my_explorer
maze = create_maze(0, 0, "static")
my_explorer = myExplorer(maze, visualize=False)

# Run the my_explorer
time_taken, moves = my_explorer.solve()
print(f"Maze solved in {time_taken:.2f} seconds")
print(f"Number of moves: {len(moves)}")
# Out:
# === Maze Exploration Statistics ===
# Total time taken: 0.00 seconds
# Total moves made: 128
# Number of backtrack operations: 0
# Average moves per second: 68600.93
# ==================================
#
# Maze solved in 0.00 seconds
# Number of moves: 128
